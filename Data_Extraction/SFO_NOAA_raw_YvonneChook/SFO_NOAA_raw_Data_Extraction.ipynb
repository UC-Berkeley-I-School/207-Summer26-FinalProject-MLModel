# %%
#Load Libraries
import os
from pathlib import Path
import pandas as pd
import gdown

# %%
def load_sfo_noaa_data():
    # Google Drive folder with SFO NOAA PSV files
    url = "https://drive.google.com/drive/folders/1qZHc7AxcL_1GaD2ZTN2n8O7lP7VmoLoh"
    folder = "data"
    output = "NOAA_SFO_2022_2026.parquet"
    
    # Download only if the folder doesn't exist
    if not os.path.exists(folder):
        gdown.download_folder(url, output=folder, quiet=False, use_cookies=False)
    
    # Load all .psv files
    psv_files = list(Path(folder).rglob("*.psv"))
    
    dfs = []
    for file in psv_files:
        df = pd.read_csv(file, sep="|", dtype=str, low_memory=False)
        dfs.append(df)
    
    # Combine and export
    noaa_sfo_df = pd.concat(dfs, ignore_index=True)
    noaa_sfo_df.to_parquet(output, index=False)
    
    return noaa_sfo_df

NOAA_SFO_df = load_sfo_noaa_data()
# Out:
# Retrieving folder contents
# Processing file 1uiyqvqDJbWGmkm8_FNe621q6vIO6YAYU GHCNh_USW00023234_2022.psv
# Processing file 1WP-Uqv2OcWlyHywI5vI9O2mrVNwg3ehl GHCNh_USW00023234_2023.psv
# Processing file 1l_8LFjJFF8A2DKfE27pELincYqPe_CR7 GHCNh_USW00023234_2024.psv
# Processing file 16_HK6-lyJPcaVCgk8fD_P4r8boICvPGn GHCNh_USW00023234_2025.psv
# Processing file 1VttV-JczJMeqAIL5TeFVsZkuyeWqvxgF GHCNh_USW00023234_2026.psv
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1uiyqvqDJbWGmkm8_FNe621q6vIO6YAYU
# To: /home/yvonne_chook/github/207-Summer26-FinalProject-MLModel/Data_Extraction/SFO_NOAA_raw_YvonneChook/data/GHCNh_USW00023234_2022.psv
# 100%|██████████| 10.7M/10.7M [00:00<00:00, 13.4MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1WP-Uqv2OcWlyHywI5vI9O2mrVNwg3ehl
# To: /home/yvonne_chook/github/207-Summer26-FinalProject-MLModel/Data_Extraction/SFO_NOAA_raw_YvonneChook/data/GHCNh_USW00023234_2023.psv
# 100%|██████████| 11.2M/11.2M [00:00<00:00, 13.8MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1l_8LFjJFF8A2DKfE27pELincYqPe_CR7
# To: /home/yvonne_chook/github/207-Summer26-FinalProject-MLModel/Data_Extraction/SFO_NOAA_raw_YvonneChook/data/GHCNh_USW00023234_2024.psv
# 100%|██████████| 12.0M/12.0M [00:00<00:00, 19.8MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=16_HK6-lyJPcaVCgk8fD_P4r8boICvPGn
# To: /home/yvonne_chook/github/207-Summer26-FinalProject-MLModel/Data_Extraction/SFO_NOAA_raw_YvonneChook/data/GHCNh_USW00023234_2025.psv
# 100%|██████████| 11.5M/11.5M [00:00<00:00, 14.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1VttV-JczJMeqAIL5TeFVsZkuyeWqvxgF
# To: /home/yvonne_chook/github/207-Summer26-FinalProject-MLModel/Data_Extraction/SFO_NOAA_raw_YvonneChook/data/GHCNh_USW00023234_2026.psv
# 100%|██████████| 18.9M/18.9M [00:00<00:00, 30.4MB/s]
# Download completed

# %%
# Analyze data downloaded
print("NOAA SFO 2022-2026:")
print(f"\nShape: {NOAA_SFO_df.shape}")

print("\nColumns and Datatypes:")
display(NOAA_SFO_df.dtypes)

print("\nData Preview:")
display(NOAA_SFO_df.head())
# Out:
# NOAA SFO 2022-2026:
#
# Shape: (89176, 329)
#
# Columns and Datatypes:
# STATION                  str
# Station_name             str
# DATE                     str
# Year                     str
# Month                    str
#                         ...
# REM_Measurement_Code     str
# REM_Quality_Code         str
# REM_Report_Type          str
# REM_Source_Code          str
# REM_Source_Station_ID    str
# Length: 329, dtype: object
# Data Preview:
#        STATION           Station_name                 DATE  Year Month Day  \
# 0  USW00023234  SAN FRANCISCO INTL AP  2024-01-01T00:00:00  2024    01  01
# 1  USW00023234  SAN FRANCISCO INTL AP  2024-01-01T00:56:00  2024    01  01
# 2  USW00023234  SAN FRANCISCO INTL AP  2024-01-01T01:56:00  2024    01  01
# 3  USW00023234  SAN FRANCISCO INTL AP  2024-01-01T02:56:00  2024    01  01
# 4  USW00023234  SAN FRANCISCO INTL AP  2024-01-01T03:00:00  2024    01  01
#
#   Hour Minute LATITUDE  LONGITUDE  ... precipitation_24_hour_Quality_Code  \
# 0   00     00  37.6197  -122.3656  ...                                NaN
# 1   00     56  37.6197  -122.3656  ...                                NaN
# 2   01     56  37.6197  -122.3656  ...                                NaN
# 3   02     56  37.6197  -122.3656  ...                                NaN
# 4   03     00  37.6197  -122.3656  ...                                NaN
#
#   precipitation_24_hour_Report_Type precipitation_24_hour_Source_Code  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
#   precipitation_24_hour_Source_Station_ID  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#                                                  REM REM_Measurement_Code  \
# 0  SYN08072494 32666 80204 10133 20100 30154 4018...                  NaN
# 1  MET083METAR KSFO 010056Z 01004KT 10SM FEW040 B...                  NaN
# 2  MET083METAR KSFO 010156Z 00000KT 10SM FEW040 B...                  NaN
# 3  MET096METAR KSFO 010256Z 00000KT 10SM FEW020 S...                  NaN
# 4  SYN06472494 32566 60000 10128 20094 30158 4018...                  NaN
#
#   REM_Quality_Code REM_Report_Type REM_Source_Code REM_Source_Station_ID
# 0              NaN            FM12             223             ICAO-KSFO
# 1              NaN            FM15             223             ICAO-KSFO
# 2              NaN            FM15             223             ICAO-KSFO
# 3              NaN            FM15             223             ICAO-KSFO
# 4              NaN            FM12             223             ICAO-KSFO
#
# [5 rows x 329 columns]
