# %%
#Load Libraries

import pandas as pd

# %%
#Load data
NOAA_SFO_df = pd.read_parquet(
    "../Data_Extraction/SFO_NOAA_raw_YvonneChook/NOAA_SFO_2022_2026.parquet"
)

NOAA_SFO_df.head()
# Out:
#        STATION           Station_name                 DATE  Year Month Day  \
# 0  USW00023234  SAN FRANCISCO INTL AP  2024-01-01T00:00:00  2024    01  01
# 1  USW00023234  SAN FRANCISCO INTL AP  2024-01-01T00:56:00  2024    01  01
# 2  USW00023234  SAN FRANCISCO INTL AP  2024-01-01T01:56:00  2024    01  01
# 3  USW00023234  SAN FRANCISCO INTL AP  2024-01-01T02:56:00  2024    01  01
# 4  USW00023234  SAN FRANCISCO INTL AP  2024-01-01T03:00:00  2024    01  01
#
#   Hour Minute LATITUDE  LONGITUDE  ... precipitation_24_hour_Quality_Code  \
# 0   00     00  37.6197  -122.3656  ...                                NaN
# 1   00     56  37.6197  -122.3656  ...                                NaN
# 2   01     56  37.6197  -122.3656  ...                                NaN
# 3   02     56  37.6197  -122.3656  ...                                NaN
# 4   03     00  37.6197  -122.3656  ...                                NaN
#
#   precipitation_24_hour_Report_Type precipitation_24_hour_Source_Code  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
#   precipitation_24_hour_Source_Station_ID  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#                                                  REM REM_Measurement_Code  \
# 0  SYN08072494 32666 80204 10133 20100 30154 4018...                  NaN
# 1  MET083METAR KSFO 010056Z 01004KT 10SM FEW040 B...                  NaN
# 2  MET083METAR KSFO 010156Z 00000KT 10SM FEW040 B...                  NaN
# 3  MET096METAR KSFO 010256Z 00000KT 10SM FEW020 S...                  NaN
# 4  SYN06472494 32566 60000 10128 20094 30158 4018...                  NaN
#
#   REM_Quality_Code REM_Report_Type REM_Source_Code REM_Source_Station_ID
# 0              NaN            FM12             223             ICAO-KSFO
# 1              NaN            FM15             223             ICAO-KSFO
# 2              NaN            FM15             223             ICAO-KSFO
# 3              NaN            FM15             223             ICAO-KSFO
# 4              NaN            FM12             223             ICAO-KSFO
#
# [5 rows x 329 columns]

# %% [markdown]
# **Review Data available**

# %%
#Check shape 
print("NOAA Extract Shape:")
print(NOAA_SFO_df.shape)
# Out:
# NOAA Extract Shape:
# (89176, 329)

# %%
# Review NOAA SFO dataset info
NOAA_summary = pd.DataFrame({
    "column_name": NOAA_SFO_df.columns,
    "dtype": NOAA_SFO_df.dtypes.values,
    "nulls_count": NOAA_SFO_df.isna().sum().values,
    "nulls_percent": (NOAA_SFO_df.isna().mean().values * 100).round(3),
    "unique_values": NOAA_SFO_df.nunique().values
})

#I want to see all data
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)


display(NOAA_summary)
# Out:
#                                         column_name dtype  nulls_count  \
# 0                                           STATION   str            0
# 1                                      Station_name   str            0
# 2                                              DATE   str            0
# 3                                              Year   str            0
# 4                                             Month   str            0
# 5                                               Day   str            0
# 6                                              Hour   str            0
# 7                                            Minute   str            0
# 8                                          LATITUDE   str            0
# 9                                         LONGITUDE   str            0
# 10                                        ELEVATION   str            0
# 11                                      temperature   str        35391
# 12                     temperature_Measurement_Code   str        89176
# 13                         temperature_Quality_Code   str        37412
# 14                          temperature_Report_Type   str        35391
# 15                          temperature_Source_Code   str        35391
# 16                    temperature_Source_Station_ID   str        35391
# 17                            dew_point_temperature   str        35391
# 18           dew_point_temperature_Measurement_Code   str        89176
# 19               dew_point_temperature_Quality_Code   str        37412
# 20                dew_point_temperature_Report_Type   str        35391
# 21                dew_point_temperature_Source_Code   str        35391
# 22          dew_point_temperature_Source_Station_ID   str        35391
# 23                           station_level_pressure   str        41563
# 24          station_level_pressure_Measurement_Code   str        87133
# 25              station_level_pressure_Quality_Code   str        43606
# 26               station_level_pressure_Report_Type   str        41563
# 27               station_level_pressure_Source_Code   str        41563
# 28         station_level_pressure_Source_Station_ID   str        41563
# 29                               sea_level_pressure   str        40957
# 30              sea_level_pressure_Measurement_Code   str        89176
# 31                  sea_level_pressure_Quality_Code   str        42744
# 32                   sea_level_pressure_Report_Type   str        40957
# 33                   sea_level_pressure_Source_Code   str        40957
# 34             sea_level_pressure_Source_Station_ID   str        40957
# 35                                   wind_direction   str        35410
# 36                  wind_direction_Measurement_Code   str        37418
# 37                      wind_direction_Quality_Code   str        39352
# 38                       wind_direction_Report_Type   str        35410
# 39                       wind_direction_Source_Code   str        35410
# 40                 wind_direction_Source_Station_ID   str        35410
# 41                                       wind_speed   str        35397
# 42                      wind_speed_Measurement_Code   str        37418
# 43                          wind_speed_Quality_Code   str        37418
# 44                           wind_speed_Report_Type   str        35397
# 45                           wind_speed_Source_Code   str        35397
# 46                     wind_speed_Source_Station_ID   str        35397
# 47                                        wind_gust   str        83017
# 48                       wind_gust_Measurement_Code   str        89176
# 49                           wind_gust_Quality_Code   str        83384
# 50                            wind_gust_Report_Type   str        83017
# 51                            wind_gust_Source_Code   str        83017
# 52                      wind_gust_Source_Station_ID   str        83017
# 53                                    precipitation   str        56049
# 54                   precipitation_Measurement_Code   str        87587
# 55                       precipitation_Quality_Code   str        56234
# 56                        precipitation_Report_Type   str        56049
# 57                        precipitation_Source_Code   str        56049
# 58                  precipitation_Source_Station_ID   str        56049
# 59                                relative_humidity   str        35391
# 60               relative_humidity_Measurement_Code   str        35391
# 61                   relative_humidity_Quality_Code   str        89165
# 62                    relative_humidity_Report_Type   str        35391
# 63                    relative_humidity_Source_Code   str        35391
# 64              relative_humidity_Source_Station_ID   str        35391
# 65                             wet_bulb_temperature   str        41565
# 66            wet_bulb_temperature_Measurement_Code   str        41565
# 67                wet_bulb_temperature_Quality_Code   str        89170
# 68                 wet_bulb_temperature_Report_Type   str        41565
# 69                 wet_bulb_temperature_Source_Code   str        41565
# 70           wet_bulb_temperature_Source_Station_ID   str        41565
# 71                                      pres_wx_MW1   str        86224
# 72                     pres_wx_MW1_Measurement_Code   str        89176
# 73                         pres_wx_MW1_Quality_Code   str        86337
# 74                          pres_wx_MW1_Report_Type   str        86224
# 75                          pres_wx_MW1_Source_Code   str        86224
# 76                    pres_wx_MW1_Source_Station_ID   str        86224
# 77                                      pres_wx_MW2   str        89174
# 78                     pres_wx_MW2_Measurement_Code   str        89176
# 79                         pres_wx_MW2_Quality_Code   str        89175
# 80                          pres_wx_MW2_Report_Type   str        89174
# 81                          pres_wx_MW2_Source_Code   str        89174
# 82                    pres_wx_MW2_Source_Station_ID   str        89174
# 83                                      pres_wx_MW3   str        89173
# 84                     pres_wx_MW3_Measurement_Code   str        89176
# 85                         pres_wx_MW3_Quality_Code   str        89176
# 86                          pres_wx_MW3_Report_Type   str        89173
# 87                          pres_wx_MW3_Source_Code   str        89173
# 88                    pres_wx_MW3_Source_Station_ID   str        89173
# 89                                      pres_wx_AU1   str        86182
# 90                     pres_wx_AU1_Measurement_Code   str        89176
# 91                         pres_wx_AU1_Quality_Code   str        86296
# 92                          pres_wx_AU1_Report_Type   str        86182
# 93                          pres_wx_AU1_Source_Code   str        86182
# 94                    pres_wx_AU1_Source_Station_ID   str        86182
# 95                                      pres_wx_AU2   str        88290
# 96                     pres_wx_AU2_Measurement_Code   str        89176
# 97                         pres_wx_AU2_Quality_Code   str        88319
# 98                          pres_wx_AU2_Report_Type   str        88290
# 99                          pres_wx_AU2_Source_Code   str        88290
# 100                   pres_wx_AU2_Source_Station_ID   str        88290
# 101                                     pres_wx_AU3   str        89167
# 102                    pres_wx_AU3_Measurement_Code   str        89176
# 103                        pres_wx_AU3_Quality_Code   str        89170
# 104                         pres_wx_AU3_Report_Type   str        89167
# 105                         pres_wx_AU3_Source_Code   str        89167
# 106                   pres_wx_AU3_Source_Station_ID   str        89167
# 107                                     pres_wx_AW1   str        85573
# 108                    pres_wx_AW1_Measurement_Code   str        89176
# 109                        pres_wx_AW1_Quality_Code   str        85687
# 110                         pres_wx_AW1_Report_Type   str        85573
# 111                         pres_wx_AW1_Source_Code   str        85573
# 112                   pres_wx_AW1_Source_Station_ID   str        85573
# 113                                     pres_wx_AW2   str        88105
# 114                    pres_wx_AW2_Measurement_Code   str        89176
# 115                        pres_wx_AW2_Quality_Code   str        88134
# 116                         pres_wx_AW2_Report_Type   str        88105
# 117                         pres_wx_AW2_Source_Code   str        88105
# 118                   pres_wx_AW2_Source_Station_ID   str        88105
# 119                                     pres_wx_AW3   str        89166
# 120                    pres_wx_AW3_Measurement_Code   str        89176
# 121                        pres_wx_AW3_Quality_Code   str        89169
# 122                         pres_wx_AW3_Report_Type   str        89166
# 123                         pres_wx_AW3_Source_Code   str        89166
# 124                   pres_wx_AW3_Source_Station_ID   str        89166
# 125                                      snow_depth   str        89176
# 126                     snow_depth_Measurement_Code   str        89176
# 127                         snow_depth_Quality_Code   str        89176
# 128                          snow_depth_Report_Type   str        89176
# 129                          snow_depth_Source_Code   str        89176
# 130                    snow_depth_Source_Station_ID   str        89176
# 131                                      visibility   str        35390
# 132                     visibility_Measurement_Code   str        37411
# 133                         visibility_Quality_Code   str        37411
# 134                          visibility_Report_Type   str        35390
# 135                          visibility_Source_Code   str        35390
# 136                    visibility_Source_Station_ID   str        35390
# 137                                       altimeter   str        44887
# 138                      altimeter_Measurement_Code   str        89176
# 139                          altimeter_Quality_Code   str        46908
# 140                           altimeter_Report_Type   str        44887
# 141                           altimeter_Source_Code   str        44887
# 142                     altimeter_Source_Station_ID   str        44887
# 143                             pressure_3hr_change   str        67861
# 144            pressure_3hr_change_Measurement_Code   str        67861
# 145                pressure_3hr_change_Quality_Code   str        68457
# 146                 pressure_3hr_change_Report_Type   str        67861
# 147                 pressure_3hr_change_Source_Code   str        67861
# 148           pressure_3hr_change_Source_Station_ID   str        67861
# 149                                   sky_condition   str        62696
# 150                  sky_condition_Measurement_Code   str        89176
# 151                      sky_condition_Quality_Code   str        62696
# 152                       sky_condition_Report_Type   str        62696
# 153                       sky_condition_Source_Code   str        62696
# 154                 sky_condition_Source_Station_ID   str        62696
# 155                            sky_condition_baseht   str        46714
# 156           sky_condition_baseht_Measurement_Code   str        46714
# 157               sky_condition_baseht_Quality_Code   str        46714
# 158                sky_condition_baseht_Report_Type   str        46714
# 159                sky_condition_baseht_Source_Code   str        46714
# 160          sky_condition_baseht_Source_Station_ID   str        46714
# 161                                  ceiling_height   str        43701
# 162                 ceiling_height_Measurement_Code   str        43701
# 163                     ceiling_height_Quality_Code   str        44758
# 164                      ceiling_height_Report_Type   str        43701
# 165                      ceiling_height_Source_Code   str        43701
# 166                ceiling_height_Source_Station_ID   str        43701
# 167                               sky_cover_layer_1   str        89176
# 168              sky_cover_layer_1_Measurement_Code   str        89176
# 169                  sky_cover_layer_1_Quality_Code   str        89176
# 170                   sky_cover_layer_1_Report_Type   str        89176
# 171                   sky_cover_layer_1_Source_Code   str        89176
# 172             sky_cover_layer_1_Source_Station_ID   str        89176
# 173                               sky_cover_layer_2   str        89176
# 174              sky_cover_layer_2_Measurement_Code   str        89176
# 175                  sky_cover_layer_2_Quality_Code   str        89176
# 176                   sky_cover_layer_2_Report_Type   str        89176
# 177                   sky_cover_layer_2_Source_Code   str        89176
# 178             sky_cover_layer_2_Source_Station_ID   str        89176
# 179                               sky_cover_layer_3   str        89176
# 180              sky_cover_layer_3_Measurement_Code   str        89176
# 181                  sky_cover_layer_3_Quality_Code   str        89176
# 182                   sky_cover_layer_3_Report_Type   str        89176
# 183                   sky_cover_layer_3_Source_Code   str        89176
# 184             sky_cover_layer_3_Source_Station_ID   str        89176
# 185                               sky_cover_layer_4   str        89176
# 186              sky_cover_layer_4_Measurement_Code   str        89176
# 187                  sky_cover_layer_4_Quality_Code   str        89176
# 188                   sky_cover_layer_4_Report_Type   str        89176
# 189                   sky_cover_layer_4_Source_Code   str        89176
# 190             sky_cover_layer_4_Source_Station_ID   str        89176
# 191                        sky_cover_layer_baseht_1   str        82523
# 192       sky_cover_layer_baseht_1_Measurement_Code   str        82523
# 193           sky_cover_layer_baseht_1_Quality_Code   str        82523
# 194            sky_cover_layer_baseht_1_Report_Type   str        82523
# 195            sky_cover_layer_baseht_1_Source_Code   str        82523
# 196      sky_cover_layer_baseht_1_Source_Station_ID   str        82523
# 197                        sky_cover_layer_baseht_2   str        89176
# 198       sky_cover_layer_baseht_2_Measurement_Code   str        89176
# 199           sky_cover_layer_baseht_2_Quality_Code   str        89176
# 200            sky_cover_layer_baseht_2_Report_Type   str        89176
# 201            sky_cover_layer_baseht_2_Source_Code   str        89176
# 202      sky_cover_layer_baseht_2_Source_Station_ID   str        89176
# 203                        sky_cover_layer_baseht_3   str        89176
# 204       sky_cover_layer_baseht_3_Measurement_Code   str        89176
# 205           sky_cover_layer_baseht_3_Quality_Code   str        89176
# 206            sky_cover_layer_baseht_3_Report_Type   str        89176
# 207            sky_cover_layer_baseht_3_Source_Code   str        89176
# 208      sky_cover_layer_baseht_3_Source_Station_ID   str        89176
# 209                        sky_cover_layer_baseht_4   str        89176
# 210       sky_cover_layer_baseht_4_Measurement_Code   str        89176
# 211           sky_cover_layer_baseht_4_Quality_Code   str        89176
# 212            sky_cover_layer_baseht_4_Report_Type   str        89176
# 213            sky_cover_layer_baseht_4_Source_Code   str        89176
# 214      sky_cover_layer_baseht_4_Source_Station_ID   str        89176
# 215                           sky_cover_summation_1   str        45664
# 216          sky_cover_summation_1_Measurement_Code   str        89176
# 217              sky_cover_summation_1_Quality_Code   str        47688
# 218               sky_cover_summation_1_Report_Type   str        45664
# 219               sky_cover_summation_1_Source_Code   str        45664
# 220         sky_cover_summation_1_Source_Station_ID   str        45664
# 221                           sky_cover_summation_2   str        64733
# 222          sky_cover_summation_2_Measurement_Code   str        89176
# 223              sky_cover_summation_2_Quality_Code   str        66035
# 224               sky_cover_summation_2_Report_Type   str        64733
# 225               sky_cover_summation_2_Source_Code   str        64733
# 226         sky_cover_summation_2_Source_Station_ID   str        64733
# 227                           sky_cover_summation_3   str        79149
# 228          sky_cover_summation_3_Measurement_Code   str        89176
# 229              sky_cover_summation_3_Quality_Code   str        79680
# 230               sky_cover_summation_3_Report_Type   str        79149
# 231               sky_cover_summation_3_Source_Code   str        79149
# 232         sky_cover_summation_3_Source_Station_ID   str        79149
# 233                           sky_cover_summation_4   str        88895
# 234          sky_cover_summation_4_Measurement_Code   str        89176
# 235              sky_cover_summation_4_Quality_Code   str        88924
# 236               sky_cover_summation_4_Report_Type   str        88895
# 237               sky_cover_summation_4_Source_Code   str        88895
# 238         sky_cover_summation_4_Source_Station_ID   str        88895
# 239                    sky_cover_summation_baseht_1   str        50082
# 240   sky_cover_summation_baseht_1_Measurement_Code   str        55498
# 241       sky_cover_summation_baseht_1_Quality_Code   str        51982
# 242        sky_cover_summation_baseht_1_Report_Type   str        50082
# 243        sky_cover_summation_baseht_1_Source_Code   str        50082
# 244  sky_cover_summation_baseht_1_Source_Station_ID   str        50082
# 245                    sky_cover_summation_baseht_2   str        64733
# 246   sky_cover_summation_baseht_2_Measurement_Code   str        68264
# 247       sky_cover_summation_baseht_2_Quality_Code   str        66035
# 248        sky_cover_summation_baseht_2_Report_Type   str        64733
# 249        sky_cover_summation_baseht_2_Source_Code   str        64733
# 250  sky_cover_summation_baseht_2_Source_Station_ID   str        64733
# 251                    sky_cover_summation_baseht_3   str        79149
# 252   sky_cover_summation_baseht_3_Measurement_Code   str        80728
# 253       sky_cover_summation_baseht_3_Quality_Code   str        79680
# 254        sky_cover_summation_baseht_3_Report_Type   str        79149
# 255        sky_cover_summation_baseht_3_Source_Code   str        79149
# 256  sky_cover_summation_baseht_3_Source_Station_ID   str        79149
# 257                    sky_cover_summation_baseht_4   str        88895
# 258   sky_cover_summation_baseht_4_Measurement_Code   str        89147
# 259       sky_cover_summation_baseht_4_Quality_Code   str        88924
# 260        sky_cover_summation_baseht_4_Report_Type   str        88895
# 261        sky_cover_summation_baseht_4_Source_Code   str        88895
# 262  sky_cover_summation_baseht_4_Source_Station_ID   str        88895
# 263                          precipitation_5_minute   str        53214
# 264         precipitation_5_minute_Measurement_Code   str        87852
# 265             precipitation_5_minute_Quality_Code   str        89176
# 266              precipitation_5_minute_Report_Type   str        89176
# 267              precipitation_5_minute_Source_Code   str        53214
# 268        precipitation_5_minute_Source_Station_ID   str        53214
# 269                         precipitation_15_minute   str        89176
# 270        precipitation_15_minute_Measurement_Code   str        89176
# 271            precipitation_15_minute_Quality_Code   str        89176
# 272             precipitation_15_minute_Report_Type   str        89176
# 273             precipitation_15_minute_Source_Code   str        89176
# 274       precipitation_15_minute_Source_Station_ID   str        89176
# 275                            precipitation_3_hour   str        88166
# 276           precipitation_3_hour_Measurement_Code   str        88834
# 277               precipitation_3_hour_Quality_Code   str        88166
# 278                precipitation_3_hour_Report_Type   str        88166
# 279                precipitation_3_hour_Source_Code   str        88166
# 280          precipitation_3_hour_Source_Station_ID   str        88166
# 281                            precipitation_6_hour   str        87634
# 282           precipitation_6_hour_Measurement_Code   str        88720
# 283               precipitation_6_hour_Quality_Code   str        87634
# 284                precipitation_6_hour_Report_Type   str        87634
# 285                precipitation_6_hour_Source_Code   str        87634
# 286          precipitation_6_hour_Source_Station_ID   str        87634
# 287                            precipitation_9_hour   str        89176
# 288           precipitation_9_hour_Measurement_Code   str        89176
# 289               precipitation_9_hour_Quality_Code   str        89176
# 290                precipitation_9_hour_Report_Type   str        89176
# 291                precipitation_9_hour_Source_Code   str        89176
# 292          precipitation_9_hour_Source_Station_ID   str        89176
# 293                           precipitation_12_hour   str        89176
# 294          precipitation_12_hour_Measurement_Code   str        89176
# 295              precipitation_12_hour_Quality_Code   str        89176
# 296               precipitation_12_hour_Report_Type   str        89176
# 297               precipitation_12_hour_Source_Code   str        89176
# 298         precipitation_12_hour_Source_Station_ID   str        89176
# 299                           precipitation_15_hour   str        89176
# 300          precipitation_15_hour_Measurement_Code   str        89176
# 301              precipitation_15_hour_Quality_Code   str        89176
# 302               precipitation_15_hour_Report_Type   str        89176
# 303               precipitation_15_hour_Source_Code   str        89176
# 304         precipitation_15_hour_Source_Station_ID   str        89176
# 305                           precipitation_18_hour   str        89176
# 306          precipitation_18_hour_Measurement_Code   str        89176
# 307              precipitation_18_hour_Quality_Code   str        89176
# 308               precipitation_18_hour_Report_Type   str        89176
# 309               precipitation_18_hour_Source_Code   str        89176
# 310         precipitation_18_hour_Source_Station_ID   str        89176
# 311                           precipitation_21_hour   str        89176
# 312          precipitation_21_hour_Measurement_Code   str        89176
# 313              precipitation_21_hour_Quality_Code   str        89176
# 314               precipitation_21_hour_Report_Type   str        89176
# 315               precipitation_21_hour_Source_Code   str        89176
# 316         precipitation_21_hour_Source_Station_ID   str        89176
# 317                           precipitation_24_hour   str        88652
# 318          precipitation_24_hour_Measurement_Code   str        89176
# 319              precipitation_24_hour_Quality_Code   str        88652
# 320               precipitation_24_hour_Report_Type   str        88652
# 321               precipitation_24_hour_Source_Code   str        88652
# 322         precipitation_24_hour_Source_Station_ID   str        88652
# 323                                             REM   str        35385
# 324                            REM_Measurement_Code   str        89176
# 325                                REM_Quality_Code   str        89176
# 326                                 REM_Report_Type   str        35385
# 327                                 REM_Source_Code   str        35385
# 328                           REM_Source_Station_ID   str        35385
#
#      nulls_percent  unique_values
# 0            0.000              1
# 1            0.000              1
# 2            0.000          89176
# 3            0.000              5
# 4            0.000             12
# 5            0.000             31
# 6            0.000             24
# 7            0.000             60
# 8            0.000              1
# 9            0.000              1
# 10           0.000              1
# 11          39.687             83
# 12         100.000              0
# 13          41.953              5
# 14          39.687              3
# 15          39.687              3
# 16          39.687              2
# 17          39.687             72
# 18         100.000              0
# 19          41.953              5
# 20          39.687              3
# 21          39.687              3
# 22          39.687              2
# 23          46.608            253
# 24          97.709              1
# 25          48.899              2
# 26          46.608              3
# 27          46.608              3
# 28          46.608              2
# 29          45.928            374
# 30         100.000              0
# 31          47.932              3
# 32          45.928              2
# 33          45.928              3
# 34          45.928              2
# 35          39.708             47
# 36          41.960              3
# 37          44.128              3
# 38          39.708              3
# 39          39.708              3
# 40          39.708              2
# 41          39.693             43
# 42          41.960              3
# 43          41.960              4
# 44          39.693              3
# 45          39.693              3
# 46          39.693              2
# 47          93.093             53
# 48         100.000              0
# 49          93.505              2
# 50          93.093              2
# 51          93.093              3
# 52          93.093              2
# 53          62.852             72
# 54          98.218              1
# 55          63.060              4
# 56          62.852              2
# 57          62.852              3
# 58          62.852              2
# 59          39.687             84
# 60          39.687              1
# 61          99.988              1
# 62          39.687              3
# 63          39.687              3
# 64          39.687              2
# 65          46.610            212
# 66          46.610              1
# 67          99.993              1
# 68          46.610              3
# 69          46.610              3
# 70          46.610              2
# 71          96.690             12
# 72         100.000              0
# 73          96.816              2
# 74          96.690              3
# 75          96.690              3
# 76          96.690              2
# 77          99.998              2
# 78         100.000              0
# 79          99.999              1
# 80          99.998              2
# 81          99.998              2
# 82          99.998              2
# 83          99.997              1
# 84         100.000              0
# 85         100.000              0
# 86          99.997              2
# 87          99.997              1
# 88          99.997              1
# 89          96.643             14
# 90         100.000              0
# 91          96.770              4
# 92          96.643              2
# 93          96.643              2
# 94          96.643              2
# 95          99.006              8
# 96         100.000              0
# 97          99.039              1
# 98          99.006              2
# 99          99.006              2
# 100         99.006              2
# 101         99.990              2
# 102        100.000              0
# 103         99.993              1
# 104         99.990              2
# 105         99.990              2
# 106         99.990              2
# 107         95.960             12
# 108        100.000              0
# 109         96.088              3
# 110         95.960              2
# 111         95.960              3
# 112         95.960              2
# 113         98.799              8
# 114        100.000              0
# 115         98.832              2
# 116         98.799              2
# 117         98.799              3
# 118         98.799              2
# 119         99.989              3
# 120        100.000              0
# 121         99.992              2
# 122         99.989              2
# 123         99.989              3
# 124         99.989              2
# 125        100.000              0
# 126        100.000              0
# 127        100.000              0
# 128        100.000              0
# 129        100.000              0
# 130        100.000              0
# 131         39.686             48
# 132         41.952              3
# 133         41.952              5
# 134         39.686              3
# 135         39.686              3
# 136         39.686              2
# 137         50.335            138
# 138        100.000              0
# 139         52.602              2
# 140         50.335              2
# 141         50.335              3
# 142         50.335              2
# 143         76.098             99
# 144         76.098              9
# 145         76.766              2
# 146         76.098              2
# 147         76.098              3
# 148         76.098              2
# 149         70.306              6
# 150        100.000              0
# 151         70.306              2
# 152         70.306              3
# 153         70.306              1
# 154         70.306              1
# 155         52.384             83
# 156         52.384              1
# 157         52.384              1
# 158         52.384              3
# 159         52.384              1
# 160         52.384              1
# 161         49.005             80
# 162         49.005              4
# 163         50.191              5
# 164         49.005              3
# 165         49.005              3
# 166         49.005              2
# 167        100.000              0
# 168        100.000              0
# 169        100.000              0
# 170        100.000              0
# 171        100.000              0
# 172        100.000              0
# 173        100.000              0
# 174        100.000              0
# 175        100.000              0
# 176        100.000              0
# 177        100.000              0
# 178        100.000              0
# 179        100.000              0
# 180        100.000              0
# 181        100.000              0
# 182        100.000              0
# 183        100.000              0
# 184        100.000              0
# 185        100.000              0
# 186        100.000              0
# 187        100.000              0
# 188        100.000              0
# 189        100.000              0
# 190        100.000              0
# 191         92.539             12
# 192         92.539              1
# 193         92.539              1
# 194         92.539              3
# 195         92.539              1
# 196         92.539              1
# 197        100.000              0
# 198        100.000              0
# 199        100.000              0
# 200        100.000              0
# 201        100.000              0
# 202        100.000              0
# 203        100.000              0
# 204        100.000              0
# 205        100.000              0
# 206        100.000              0
# 207        100.000              0
# 208        100.000              0
# 209        100.000              0
# 210        100.000              0
# 211        100.000              0
# 212        100.000              0
# 213        100.000              0
# 214        100.000              0
# 215         51.207              7
# 216        100.000              0
# 217         53.476              3
# 218         51.207              2
# 219         51.207              3
# 220         51.207              2
# 221         72.590              4
# 222        100.000              0
# 223         74.050              3
# 224         72.590              2
# 225         72.590              3
# 226         72.590              2
# 227         88.756              4
# 228        100.000              0
# 229         89.351              2
# 230         88.756              2
# 231         88.756              3
# 232         88.756              2
# 233         99.685              4
# 234        100.000              0
# 235         99.717              1
# 236         99.685              2
# 237         99.685              2
# 238         99.685              1
# 239         56.161             75
# 240         62.234              4
# 241         58.291              3
# 242         56.161              2
# 243         56.161              3
# 244         56.161              2
# 245         72.590             73
# 246         76.550              4
# 247         74.050              3
# 248         72.590              2
# 249         72.590              3
# 250         72.590              2
# 251         88.756             73
# 252         90.527              2
# 253         89.351              2
# 254         88.756              2
# 255         88.756              3
# 256         88.756              2
# 257         99.685              7
# 258         99.967              1
# 259         99.717              1
# 260         99.685              2
# 261         99.685              2
# 262         99.685              1
# 263         59.673             13
# 264         98.515              1
# 265        100.000              0
# 266        100.000              0
# 267         59.673              1
# 268         59.673              1
# 269        100.000              0
# 270        100.000              0
# 271        100.000              0
# 272        100.000              0
# 273        100.000              0
# 274        100.000              0
# 275         98.867             68
# 276         99.616              1
# 277         98.867              1
# 278         98.867              2
# 279         98.867              1
# 280         98.867              1
# 281         98.271            104
# 282         99.489              1
# 283         98.271              1
# 284         98.271              2
# 285         98.271              1
# 286         98.271              1
# 287        100.000              0
# 288        100.000              0
# 289        100.000              0
# 290        100.000              0
# 291        100.000              0
# 292        100.000              0
# 293        100.000              0
# 294        100.000              0
# 295        100.000              0
# 296        100.000              0
# 297        100.000              0
# 298        100.000              0
# 299        100.000              0
# 300        100.000              0
# 301        100.000              0
# 302        100.000              0
# 303        100.000              0
# 304        100.000              0
# 305        100.000              0
# 306        100.000              0
# 307        100.000              0
# 308        100.000              0
# 309        100.000              0
# 310        100.000              0
# 311        100.000              0
# 312        100.000              0
# 313        100.000              0
# 314        100.000              0
# 315        100.000              0
# 316        100.000              0
# 317         99.412            132
# 318        100.000              0
# 319         99.412              1
# 320         99.412              2
# 321         99.412              1
# 322         99.412              1
# 323         39.680          53791
# 324        100.000              0
# 325        100.000              0
# 326         39.680              3
# 327         39.680              3
# 328         39.680              2

# %% [markdown]
# **Clean Data Type**

# %%
#Convert DATE column to datatime

NOAA_SFO_cleaned = NOAA_SFO_df

NOAA_SFO_cleaned["DATE"] = pd.to_datetime(NOAA_SFO_cleaned["DATE"])

#check
NOAA_SFO_cleaned["DATE"].dtype
# Out:
# dtype('<M8[us]')

# %%
# convert any date time components to ints

#specify columns and intended datatype
date_str_to_ints = [
    "Year",
    "Month",
    "Day",
    "Hour",
    "Minute"
]

for col in date_str_to_ints:
    NOAA_SFO_cleaned[col] = pd.to_numeric(NOAA_SFO_cleaned[col])

# %%
# convert any location features into floats
location_str_to_floats = [
    "LATITUDE", 
    "LONGITUDE", 
    "ELEVATION"
]

for col in location_str_to_floats:
    NOAA_SFO_cleaned[col] = pd.to_numeric(NOAA_SFO_cleaned[col])

# %%
#any weather measurement to numeric value
numeric_weather_cols = [
    "temperature",
    "dew_point_temperature",
    "station_level_pressure",
    "sea_level_pressure",
    "wind_direction",
    "wind_speed",
    "wind_gust",
    "precipitation",
    "relative_humidity",
    "wet_bulb_temperature",
    "snow_depth",
    "visibility",
    "altimeter",
    "pressure_3hr_change",
    "sky_condition_baseht",
    "ceiling_height",
    "sky_cover_layer_1",
    "sky_cover_layer_2",
    "sky_cover_layer_3",
    "sky_cover_layer_4",
    "sky_cover_layer_baseht_1",
    "sky_cover_layer_baseht_2",
    "sky_cover_layer_baseht_3",
    "sky_cover_layer_baseht_4",
    "sky_cover_summation_baseht_1",
    "sky_cover_summation_baseht_2",
    "sky_cover_summation_baseht_3",
    "sky_cover_summation_baseht_4",
    "precipitation_5_minute",
    "precipitation_15_minute",
    "precipitation_3_hour",
    "precipitation_6_hour",
    "precipitation_9_hour",
    "precipitation_12_hour",
    "precipitation_15_hour",
    "precipitation_18_hour",
    "precipitation_21_hour",
    "precipitation_24_hour"
]

for col in numeric_weather_cols:
    if col in NOAA_SFO_cleaned.columns:
        NOAA_SFO_cleaned[col] = pd.to_numeric(NOAA_SFO_cleaned[col])

# %%
# filter for unique entries only
NOAA_SFO_cleaned = NOAA_SFO_cleaned.drop_duplicates()

#fiter cases where columns are entirely null
NOAA_SFO_cleaned = NOAA_SFO_cleaned.dropna(axis=1, how="all")

#Check shape
print(NOAA_SFO_cleaned.shape)
# Out:
# (89176, 220)

# %% [markdown]
# **Comment:** No change in shape, indicating all entries have unique data combinations

# %%
#review final version with dtype cleaning
NOAA_summary_cleaned = pd.DataFrame({
    "column_name": NOAA_SFO_cleaned.columns,
    "dtype": NOAA_SFO_cleaned.dtypes.values,
    "nulls_count": NOAA_SFO_cleaned.isna().sum().values,
    "nulls_percent": (NOAA_SFO_cleaned.isna().mean().values * 100).round(3),
    "unique_values": NOAA_SFO_cleaned.nunique().values
})

display(NOAA_summary_cleaned)
# Out:
#                                         column_name           dtype  \
# 0                                           STATION             str
# 1                                      Station_name             str
# 2                                              DATE  datetime64[us]
# 3                                              Year           int64
# 4                                             Month           int64
# 5                                               Day           int64
# 6                                              Hour           int64
# 7                                            Minute           int64
# 8                                          LATITUDE         float64
# 9                                         LONGITUDE         float64
# 10                                        ELEVATION         float64
# 11                                      temperature         float64
# 12                         temperature_Quality_Code             str
# 13                          temperature_Report_Type             str
# 14                          temperature_Source_Code             str
# 15                    temperature_Source_Station_ID             str
# 16                            dew_point_temperature         float64
# 17               dew_point_temperature_Quality_Code             str
# 18                dew_point_temperature_Report_Type             str
# 19                dew_point_temperature_Source_Code             str
# 20          dew_point_temperature_Source_Station_ID             str
# 21                           station_level_pressure         float64
# 22          station_level_pressure_Measurement_Code             str
# 23              station_level_pressure_Quality_Code             str
# 24               station_level_pressure_Report_Type             str
# 25               station_level_pressure_Source_Code             str
# 26         station_level_pressure_Source_Station_ID             str
# 27                               sea_level_pressure         float64
# 28                  sea_level_pressure_Quality_Code             str
# 29                   sea_level_pressure_Report_Type             str
# 30                   sea_level_pressure_Source_Code             str
# 31             sea_level_pressure_Source_Station_ID             str
# 32                                   wind_direction         float64
# 33                  wind_direction_Measurement_Code             str
# 34                      wind_direction_Quality_Code             str
# 35                       wind_direction_Report_Type             str
# 36                       wind_direction_Source_Code             str
# 37                 wind_direction_Source_Station_ID             str
# 38                                       wind_speed         float64
# 39                      wind_speed_Measurement_Code             str
# 40                          wind_speed_Quality_Code             str
# 41                           wind_speed_Report_Type             str
# 42                           wind_speed_Source_Code             str
# 43                     wind_speed_Source_Station_ID             str
# 44                                        wind_gust         float64
# 45                           wind_gust_Quality_Code             str
# 46                            wind_gust_Report_Type             str
# 47                            wind_gust_Source_Code             str
# 48                      wind_gust_Source_Station_ID             str
# 49                                    precipitation         float64
# 50                   precipitation_Measurement_Code             str
# 51                       precipitation_Quality_Code             str
# 52                        precipitation_Report_Type             str
# 53                        precipitation_Source_Code             str
# 54                  precipitation_Source_Station_ID             str
# 55                                relative_humidity         float64
# 56               relative_humidity_Measurement_Code             str
# 57                   relative_humidity_Quality_Code             str
# 58                    relative_humidity_Report_Type             str
# 59                    relative_humidity_Source_Code             str
# 60              relative_humidity_Source_Station_ID             str
# 61                             wet_bulb_temperature         float64
# 62            wet_bulb_temperature_Measurement_Code             str
# 63                wet_bulb_temperature_Quality_Code             str
# 64                 wet_bulb_temperature_Report_Type             str
# 65                 wet_bulb_temperature_Source_Code             str
# 66           wet_bulb_temperature_Source_Station_ID             str
# 67                                      pres_wx_MW1             str
# 68                         pres_wx_MW1_Quality_Code             str
# 69                          pres_wx_MW1_Report_Type             str
# 70                          pres_wx_MW1_Source_Code             str
# 71                    pres_wx_MW1_Source_Station_ID             str
# 72                                      pres_wx_MW2             str
# 73                         pres_wx_MW2_Quality_Code             str
# 74                          pres_wx_MW2_Report_Type             str
# 75                          pres_wx_MW2_Source_Code             str
# 76                    pres_wx_MW2_Source_Station_ID             str
# 77                                      pres_wx_MW3             str
# 78                          pres_wx_MW3_Report_Type             str
# 79                          pres_wx_MW3_Source_Code             str
# 80                    pres_wx_MW3_Source_Station_ID             str
# 81                                      pres_wx_AU1             str
# 82                         pres_wx_AU1_Quality_Code             str
# 83                          pres_wx_AU1_Report_Type             str
# 84                          pres_wx_AU1_Source_Code             str
# 85                    pres_wx_AU1_Source_Station_ID             str
# 86                                      pres_wx_AU2             str
# 87                         pres_wx_AU2_Quality_Code             str
# 88                          pres_wx_AU2_Report_Type             str
# 89                          pres_wx_AU2_Source_Code             str
# 90                    pres_wx_AU2_Source_Station_ID             str
# 91                                      pres_wx_AU3             str
# 92                         pres_wx_AU3_Quality_Code             str
# 93                          pres_wx_AU3_Report_Type             str
# 94                          pres_wx_AU3_Source_Code             str
# 95                    pres_wx_AU3_Source_Station_ID             str
# 96                                      pres_wx_AW1             str
# 97                         pres_wx_AW1_Quality_Code             str
# 98                          pres_wx_AW1_Report_Type             str
# 99                          pres_wx_AW1_Source_Code             str
# 100                   pres_wx_AW1_Source_Station_ID             str
# 101                                     pres_wx_AW2             str
# 102                        pres_wx_AW2_Quality_Code             str
# 103                         pres_wx_AW2_Report_Type             str
# 104                         pres_wx_AW2_Source_Code             str
# 105                   pres_wx_AW2_Source_Station_ID             str
# 106                                     pres_wx_AW3             str
# 107                        pres_wx_AW3_Quality_Code             str
# 108                         pres_wx_AW3_Report_Type             str
# 109                         pres_wx_AW3_Source_Code             str
# 110                   pres_wx_AW3_Source_Station_ID             str
# 111                                      visibility         float64
# 112                     visibility_Measurement_Code             str
# 113                         visibility_Quality_Code             str
# 114                          visibility_Report_Type             str
# 115                          visibility_Source_Code             str
# 116                    visibility_Source_Station_ID             str
# 117                                       altimeter         float64
# 118                          altimeter_Quality_Code             str
# 119                           altimeter_Report_Type             str
# 120                           altimeter_Source_Code             str
# 121                     altimeter_Source_Station_ID             str
# 122                             pressure_3hr_change         float64
# 123            pressure_3hr_change_Measurement_Code             str
# 124                pressure_3hr_change_Quality_Code             str
# 125                 pressure_3hr_change_Report_Type             str
# 126                 pressure_3hr_change_Source_Code             str
# 127           pressure_3hr_change_Source_Station_ID             str
# 128                                   sky_condition             str
# 129                      sky_condition_Quality_Code             str
# 130                       sky_condition_Report_Type             str
# 131                       sky_condition_Source_Code             str
# 132                 sky_condition_Source_Station_ID             str
# 133                            sky_condition_baseht         float64
# 134           sky_condition_baseht_Measurement_Code             str
# 135               sky_condition_baseht_Quality_Code             str
# 136                sky_condition_baseht_Report_Type             str
# 137                sky_condition_baseht_Source_Code             str
# 138          sky_condition_baseht_Source_Station_ID             str
# 139                                  ceiling_height         float64
# 140                 ceiling_height_Measurement_Code             str
# 141                     ceiling_height_Quality_Code             str
# 142                      ceiling_height_Report_Type             str
# 143                      ceiling_height_Source_Code             str
# 144                ceiling_height_Source_Station_ID             str
# 145                        sky_cover_layer_baseht_1         float64
# 146       sky_cover_layer_baseht_1_Measurement_Code             str
# 147           sky_cover_layer_baseht_1_Quality_Code             str
# 148            sky_cover_layer_baseht_1_Report_Type             str
# 149            sky_cover_layer_baseht_1_Source_Code             str
# 150      sky_cover_layer_baseht_1_Source_Station_ID             str
# 151                           sky_cover_summation_1             str
# 152              sky_cover_summation_1_Quality_Code             str
# 153               sky_cover_summation_1_Report_Type             str
# 154               sky_cover_summation_1_Source_Code             str
# 155         sky_cover_summation_1_Source_Station_ID             str
# 156                           sky_cover_summation_2             str
# 157              sky_cover_summation_2_Quality_Code             str
# 158               sky_cover_summation_2_Report_Type             str
# 159               sky_cover_summation_2_Source_Code             str
# 160         sky_cover_summation_2_Source_Station_ID             str
# 161                           sky_cover_summation_3             str
# 162              sky_cover_summation_3_Quality_Code             str
# 163               sky_cover_summation_3_Report_Type             str
# 164               sky_cover_summation_3_Source_Code             str
# 165         sky_cover_summation_3_Source_Station_ID             str
# 166                           sky_cover_summation_4             str
# 167              sky_cover_summation_4_Quality_Code             str
# 168               sky_cover_summation_4_Report_Type             str
# 169               sky_cover_summation_4_Source_Code             str
# 170         sky_cover_summation_4_Source_Station_ID             str
# 171                    sky_cover_summation_baseht_1         float64
# 172   sky_cover_summation_baseht_1_Measurement_Code             str
# 173       sky_cover_summation_baseht_1_Quality_Code             str
# 174        sky_cover_summation_baseht_1_Report_Type             str
# 175        sky_cover_summation_baseht_1_Source_Code             str
# 176  sky_cover_summation_baseht_1_Source_Station_ID             str
# 177                    sky_cover_summation_baseht_2         float64
# 178   sky_cover_summation_baseht_2_Measurement_Code             str
# 179       sky_cover_summation_baseht_2_Quality_Code             str
# 180        sky_cover_summation_baseht_2_Report_Type             str
# 181        sky_cover_summation_baseht_2_Source_Code             str
# 182  sky_cover_summation_baseht_2_Source_Station_ID             str
# 183                    sky_cover_summation_baseht_3         float64
# 184   sky_cover_summation_baseht_3_Measurement_Code             str
# 185       sky_cover_summation_baseht_3_Quality_Code             str
# 186        sky_cover_summation_baseht_3_Report_Type             str
# 187        sky_cover_summation_baseht_3_Source_Code             str
# 188  sky_cover_summation_baseht_3_Source_Station_ID             str
# 189                    sky_cover_summation_baseht_4         float64
# 190   sky_cover_summation_baseht_4_Measurement_Code             str
# 191       sky_cover_summation_baseht_4_Quality_Code             str
# 192        sky_cover_summation_baseht_4_Report_Type             str
# 193        sky_cover_summation_baseht_4_Source_Code             str
# 194  sky_cover_summation_baseht_4_Source_Station_ID             str
# 195                          precipitation_5_minute         float64
# 196         precipitation_5_minute_Measurement_Code             str
# 197              precipitation_5_minute_Source_Code             str
# 198        precipitation_5_minute_Source_Station_ID             str
# 199                            precipitation_3_hour         float64
# 200           precipitation_3_hour_Measurement_Code             str
# 201               precipitation_3_hour_Quality_Code             str
# 202                precipitation_3_hour_Report_Type             str
# 203                precipitation_3_hour_Source_Code             str
# 204          precipitation_3_hour_Source_Station_ID             str
# 205                            precipitation_6_hour         float64
# 206           precipitation_6_hour_Measurement_Code             str
# 207               precipitation_6_hour_Quality_Code             str
# 208                precipitation_6_hour_Report_Type             str
# 209                precipitation_6_hour_Source_Code             str
# 210          precipitation_6_hour_Source_Station_ID             str
# 211                           precipitation_24_hour         float64
# 212              precipitation_24_hour_Quality_Code             str
# 213               precipitation_24_hour_Report_Type             str
# 214               precipitation_24_hour_Source_Code             str
# 215         precipitation_24_hour_Source_Station_ID             str
# 216                                             REM             str
# 217                                 REM_Report_Type             str
# 218                                 REM_Source_Code             str
# 219                           REM_Source_Station_ID             str
#
#      nulls_count  nulls_percent  unique_values
# 0              0          0.000              1
# 1              0          0.000              1
# 2              0          0.000          89176
# 3              0          0.000              5
# 4              0          0.000             12
# 5              0          0.000             31
# 6              0          0.000             24
# 7              0          0.000             60
# 8              0          0.000              1
# 9              0          0.000              1
# 10             0          0.000              1
# 11         35391         39.687             83
# 12         37412         41.953              5
# 13         35391         39.687              3
# 14         35391         39.687              3
# 15         35391         39.687              2
# 16         35391         39.687             72
# 17         37412         41.953              5
# 18         35391         39.687              3
# 19         35391         39.687              3
# 20         35391         39.687              2
# 21         41563         46.608            253
# 22         87133         97.709              1
# 23         43606         48.899              2
# 24         41563         46.608              3
# 25         41563         46.608              3
# 26         41563         46.608              2
# 27         40957         45.928            374
# 28         42744         47.932              3
# 29         40957         45.928              2
# 30         40957         45.928              3
# 31         40957         45.928              2
# 32         35410         39.708             38
# 33         37418         41.960              3
# 34         39352         44.128              3
# 35         35410         39.708              3
# 36         35410         39.708              3
# 37         35410         39.708              2
# 38         35397         39.693             43
# 39         37418         41.960              3
# 40         37418         41.960              4
# 41         35397         39.693              3
# 42         35397         39.693              3
# 43         35397         39.693              2
# 44         83017         93.093             53
# 45         83384         93.505              2
# 46         83017         93.093              2
# 47         83017         93.093              3
# 48         83017         93.093              2
# 49         56049         62.852             72
# 50         87587         98.218              1
# 51         56234         63.060              4
# 52         56049         62.852              2
# 53         56049         62.852              3
# 54         56049         62.852              2
# 55         35391         39.687             84
# 56         35391         39.687              1
# 57         89165         99.988              1
# 58         35391         39.687              3
# 59         35391         39.687              3
# 60         35391         39.687              2
# 61         41565         46.610            212
# 62         41565         46.610              1
# 63         89170         99.993              1
# 64         41565         46.610              3
# 65         41565         46.610              3
# 66         41565         46.610              2
# 67         86224         96.690             12
# 68         86337         96.816              2
# 69         86224         96.690              3
# 70         86224         96.690              3
# 71         86224         96.690              2
# 72         89174         99.998              2
# 73         89175         99.999              1
# 74         89174         99.998              2
# 75         89174         99.998              2
# 76         89174         99.998              2
# 77         89173         99.997              1
# 78         89173         99.997              2
# 79         89173         99.997              1
# 80         89173         99.997              1
# 81         86182         96.643             14
# 82         86296         96.770              4
# 83         86182         96.643              2
# 84         86182         96.643              2
# 85         86182         96.643              2
# 86         88290         99.006              8
# 87         88319         99.039              1
# 88         88290         99.006              2
# 89         88290         99.006              2
# 90         88290         99.006              2
# 91         89167         99.990              2
# 92         89170         99.993              1
# 93         89167         99.990              2
# 94         89167         99.990              2
# 95         89167         99.990              2
# 96         85573         95.960             12
# 97         85687         96.088              3
# 98         85573         95.960              2
# 99         85573         95.960              3
# 100        85573         95.960              2
# 101        88105         98.799              8
# 102        88134         98.832              2
# 103        88105         98.799              2
# 104        88105         98.799              3
# 105        88105         98.799              2
# 106        89166         99.989              3
# 107        89169         99.992              2
# 108        89166         99.989              2
# 109        89166         99.989              3
# 110        89166         99.989              2
# 111        35390         39.686             48
# 112        37411         41.952              3
# 113        37411         41.952              5
# 114        35390         39.686              3
# 115        35390         39.686              3
# 116        35390         39.686              2
# 117        44887         50.335            138
# 118        46908         52.602              2
# 119        44887         50.335              2
# 120        44887         50.335              3
# 121        44887         50.335              2
# 122        67861         76.098             98
# 123        67861         76.098              9
# 124        68457         76.766              2
# 125        67861         76.098              2
# 126        67861         76.098              3
# 127        67861         76.098              2
# 128        62696         70.306              6
# 129        62696         70.306              2
# 130        62696         70.306              3
# 131        62696         70.306              1
# 132        62696         70.306              1
# 133        46714         52.384             83
# 134        46714         52.384              1
# 135        46714         52.384              1
# 136        46714         52.384              3
# 137        46714         52.384              1
# 138        46714         52.384              1
# 139        43701         49.005             80
# 140        43701         49.005              4
# 141        44758         50.191              5
# 142        43701         49.005              3
# 143        43701         49.005              3
# 144        43701         49.005              2
# 145        82523         92.539             12
# 146        82523         92.539              1
# 147        82523         92.539              1
# 148        82523         92.539              3
# 149        82523         92.539              1
# 150        82523         92.539              1
# 151        45664         51.207              7
# 152        47688         53.476              3
# 153        45664         51.207              2
# 154        45664         51.207              3
# 155        45664         51.207              2
# 156        64733         72.590              4
# 157        66035         74.050              3
# 158        64733         72.590              2
# 159        64733         72.590              3
# 160        64733         72.590              2
# 161        79149         88.756              4
# 162        79680         89.351              2
# 163        79149         88.756              2
# 164        79149         88.756              3
# 165        79149         88.756              2
# 166        88895         99.685              4
# 167        88924         99.717              1
# 168        88895         99.685              2
# 169        88895         99.685              2
# 170        88895         99.685              1
# 171        50082         56.161             75
# 172        55498         62.234              4
# 173        51982         58.291              3
# 174        50082         56.161              2
# 175        50082         56.161              3
# 176        50082         56.161              2
# 177        64733         72.590             73
# 178        68264         76.550              4
# 179        66035         74.050              3
# 180        64733         72.590              2
# 181        64733         72.590              3
# 182        64733         72.590              2
# 183        79149         88.756             73
# 184        80728         90.527              2
# 185        79680         89.351              2
# 186        79149         88.756              2
# 187        79149         88.756              3
# 188        79149         88.756              2
# 189        88895         99.685              7
# 190        89147         99.967              1
# 191        88924         99.717              1
# 192        88895         99.685              2
# 193        88895         99.685              2
# 194        88895         99.685              1
# 195        53214         59.673             13
# 196        87852         98.515              1
# 197        53214         59.673              1
# 198        53214         59.673              1
# 199        88166         98.867             68
# 200        88834         99.616              1
# 201        88166         98.867              1
# 202        88166         98.867              2
# 203        88166         98.867              1
# 204        88166         98.867              1
# 205        87634         98.271            104
# 206        88720         99.489              1
# 207        87634         98.271              1
# 208        87634         98.271              2
# 209        87634         98.271              1
# 210        87634         98.271              1
# 211        88652         99.412            132
# 212        88652         99.412              1
# 213        88652         99.412              2
# 214        88652         99.412              1
# 215        88652         99.412              1
# 216        35385         39.680          53791
# 217        35385         39.680              3
# 218        35385         39.680              3
# 219        35385         39.680              2

# %% [markdown]
# **Sort Data**

# %%
#sort data from ascending order
NOAA_SFO_cleaned = NOAA_SFO_cleaned.sort_values(
    by="DATE",
    ascending=True
).reset_index(drop=True)

#Check
NOAA_SFO_cleaned[["DATE", "Year", "Month", "Day", "Hour", "Minute"]].head()
# Out:
#                  DATE  Year  Month  Day  Hour  Minute
# 0 2022-01-01 00:00:00  2022      1    1     0       0
# 1 2022-01-01 00:56:00  2022      1    1     0      56
# 2 2022-01-01 01:56:00  2022      1    1     1      56
# 3 2022-01-01 02:56:00  2022      1    1     2      56
# 4 2022-01-01 03:56:00  2022      1    1     3      56

# %% [markdown]
# **Save Data**

# %%
NOAA_SFO_cleaned.to_parquet("data/NOAA_SFO_2022_2026_cleaned.parquet")
